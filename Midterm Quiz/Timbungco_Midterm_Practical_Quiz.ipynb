# %% [markdown]
# <a href="https://colab.research.google.com/github/IanJude/AIDA-2---Machine-Learning/blob/main/Midterm%20Quiz/Timbungco_Midterm_Practical_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $_{\text {Midterm Quiz Answered by I.J. Timbungco | Student Number: 201913153 | 2022 | Fudamentals of Machine Learning}}$

# %%
import numpy as np 
import pandas as pd 

from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from scipy import stats
import matplotlib.pyplot as plt 
plt.rc("font", size=14)

# %% [markdown]
# ###Q1. Read the dataset in xls file.

# %%
# Dataset
netflix_data_path = 'https://github.com/IanJude/AIDA-2---Machine-Learning/blob/main/Midterm%20Quiz/netflix_titles.xlsx?raw=true'
df_netflix = pd.read_excel(netflix_data_path)
df_netflix
# Out:
#       duration_minutes  duration_seasons   type  \
# 0                   90               NaN  Movie
# 1                   94               NaN  Movie
# 2                   99               NaN  Movie
# 3                  110               NaN  Movie
# 4                   60               NaN  Movie
# ...                ...               ...    ...
# 4260                70               NaN  Movie
# 4261               102               NaN  Movie
# 4262                88               NaN  Movie
# 4263               109               NaN  Movie
# 4264                60               NaN  Movie
#
#                                         title date_added  release_year rating  \
# 0     Norm of the North: King Sized Adventure 2019-09-09          2019  TV-PG
# 1                  Jandino: Whatever it Takes 2016-09-09          2016  TV-MA
# 2                                #realityhigh 2017-09-08          2017  TV-14
# ...

# %%
print('The number of samples into the netflix titles dataset is {}.'.format(df_netflix.shape[0]))
# Out:
# The number of samples into the netflix titles dataset is 4265.

# %% [markdown]
# ###Q3. Create a python program that will show the descriptive analysis of the datasets ( Count, min, max, standard deviation, 75%,50%and 25%)

# %%
df_netflix.count()
# Out:
# duration_minutes    4265
# duration_seasons       0
# type                4265
# title               4265
# date_added          4265
# release_year        4265
# rating              4256
# description         4264
# show_id             4263
# dtype: int64

# %%
df_netflix.head()
# Out:
#    duration_minutes  duration_seasons   type  \
# 0                90               NaN  Movie
# 1                94               NaN  Movie
# 2                99               NaN  Movie
# 3               110               NaN  Movie
# 4                60               NaN  Movie
#
#                                      title date_added  release_year rating  \
# 0  Norm of the North: King Sized Adventure 2019-09-09          2019  TV-PG
# 1               Jandino: Whatever it Takes 2016-09-09          2016  TV-MA
# 2                             #realityhigh 2017-09-08          2017  TV-14
# 3                                 Automata 2017-09-08          2014      R
# 4       Fabrizio Copano: Solo pienso en mi 2017-09-08          2017  TV-MA
#
#                                          description     show_id
# 0  Before planning an awesome wedding for his gra...  81145628.0
# 1  Jandino Asporaat riffs on the challenges of ra...  80117401.0
# ...

# %%
df_netflix.tail()
# Out:
#       duration_minutes  duration_seasons   type  \
# 4260                70               NaN  Movie
# 4261               102               NaN  Movie
# 4262                88               NaN  Movie
# 4263               109               NaN  Movie
# 4264                60               NaN  Movie
#
#                                        title date_added  release_year rating  \
# 4260                         Frank and Cindy 2016-04-01          2007  TV-MA
# 4261                         Frank and Cindy 2016-04-01          2015      R
# 4262                                 Iverson 2016-04-01          2014     NR
# 4263     Jeremy Scott: The People's Designer 2016-04-01          2015  PG-13
# 4264  Little Baby Bum: Nursery Rhyme Friends 2016-04-02          2016    NaN
#
#                                             description     show_id
# 4260  Frank was a rising pop star when he married Ci...  80085438.0
# 4261  A student filmmaker vengefully turns his camer...  80085439.0
# ...

# %%
df_netflix.describe()
# Out:
#        duration_minutes  duration_seasons  release_year       show_id
# count       4265.000000               0.0   4265.000000  4.263000e+03
# mean          99.100821               NaN   2012.371395  7.561884e+07
# std           28.074857               NaN      9.679112  1.287895e+07
# min            3.000000               NaN   1942.000000  2.477470e+05
# 25%           86.000000               NaN   2012.000000  7.030419e+07
# 50%           98.000000               NaN   2016.000000  8.015858e+07
# 75%          115.000000               NaN   2017.000000  8.099169e+07
# max          312.000000               NaN   2020.000000  8.123573e+07

# %% [markdown]
# ###Q4. Draw a scatter plot.

# %%
x = df_netflix['release_year']
y = df_netflix['duration_minutes']

plt.scatter(x,y, color='green')

# %% [markdown]
# ###Q5 Create a python program that will plot and show the regression line and regression coefficient.

# %%
x = df_netflix['release_year']
y = df_netflix['duration_minutes']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y, color='green')
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# ###Q6. Create a python code to predict future values. Is linear regression the appropriate method to use to predict future values? Why?

# %% [markdown]
# ```
# slope,intercept,r,p,std_err = stats.lingress(x,y)
#
# def func(x):
#   return slope * x + intercept
# ```
